# %%
# %matplotlib inline
import matplotlib.pylab as plt

from numpy import load,save
import numpy as np

# %%
# nu / delta Ratio
rationumber=20
RatioSize=[rationumber,rationumber]
RatioMatrix=np.zeros(RatioSize)
L=10000.

nubound=[0.05,0.09]
nu1=np.linspace(nubound[0],nubound[1],rationumber)
nuary=nu1*L

deltabound=[100000,300000]

#nuary=linspace(nubound[0],nubound[1],rationumber);
delary=np.linspace(deltabound[0],deltabound[1],rationumber);
lifeL=1
mu1=mut1=muh1=0.6

# %%
RatioMatrix=load('deltanu.npy')

# %%
#from matplotlib import rc
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('fromfont',**{'family':'serif','serif':['Palatino']})
#rc('text', usetex=True)
plt.figure(figsize=(8,8))

#contourf(2*RatioMatrix,origin="lower",extent=[deltabound[0],deltabound[1],nubound[0],nubound[1]])
#plt.contour(delary,nuary,RatioMatrix,extent=[deltabound[0],deltabound[1],nuary[0],nuary[-1]],levels=[0,1,2,3],linewidths=4)#,origin="lower",extent=[deltabound[0],deltabound[1],nubound[0],nubound[1]])
plt.contour(SampleMatrix[0:75,0:75].transpose(),extent=[0.6,0.75,en[0],0.75],levels=[-2,-0.5,0.5,1,2,3,4],linestyles='dotted',linewidths=4)

#imshow(2*RatioMatrix,origin='lower') #,extent=[deltabound[0],deltabound[1],nubound[0],nubound[1]])
#xticks(nuary,delary)
#yticks(nuary)
plt.ylabel(r'Advection $\nu\quad(m d^{-1})$',size=18)
plt.xlabel(r'diffusivity $\delta\quad(m^2 d^{-1})$',size=18)
#title(r'$K_1=0.002,K_2=0.005,\mu_1=0.64$',size=16)
#text(185000,575,'$\longrightarrow$ Species II alive',size=16,color='orange');
#text(195000,620,'$\longrightarrow$ Species I alive',size=16,color='blue');
plt.text(150000,760,'Species dies out',size=20);
plt.text(210000,610,'Species persisnts',size=20);

#title('$k_1=0.002,k_2=0.005$',size=18)
plt.grid(True)
#colorbar()
plt.savefig('delmut.eps')
#print(u1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4b0a8a29c6c7> in <module>()
#       8 #contourf(2*RatioMatrix,origin="lower",extent=[deltabound[0],deltabound[1],nubound[0],nubound[1]])
#       9 #plt.contour(delary,nuary,RatioMatrix,extent=[deltabound[0],deltabound[1],nuary[0],nuary[-1]],levels=[0,1,2,3],linewidths=4)#,origin="lower",extent=[deltabound[0],deltabound[1],nubound[0],nubound[1]])
# ---> 10 plt.contour(SampleMatrix[0:75,0:75].transpose(),extent=[0.6,0.75,en[0],0.75],levels=[-2,-0.5,0.5,1,2,3,4],linestyles='dotted',linewidths=4)
#      11
#      12 #imshow(2*RatioMatrix,origin='lower') #,extent=[deltabound[0],deltabound[1],nubound[0],nubound[1]])
#
# NameError: name 'SampleMatrix' is not defined

# %%
Snumber=100
SampleSize=[Snumber,Snumber]
SampleMatrix=np.zeros(SampleSize)

em=np.linspace(0.6,0.8,Snumber);
en=np.linspace(0.6,0.8,Snumber);

SampleMatrix=load('map1.npy')

# %%
#from matplotlib import rc

plt.figure(figsize=(8,8))
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
#rc('text', usetex=True)

#rcParams['text.usetex'] = True
#imshow(SampleMatrix.transpose(),origin='lower',extent=[em[0],em[-1],en[0],en[-1]])
#contour(SampleMatrix.transpose(),extent=[em[0],em[-1],en[0],en[-1]],linestyles='dotted',linewidths=4)
plt.contour(SampleMatrix[0:75,0:75].transpose(),extent=[0.6,0.75,en[0],0.75],levels=[-2,-0.5,0.5,1,2,3,4],linestyles='dotted',linewidths=4)
#plt.contour(delary,nuary,RatioMatrix,extent=[deltabound[0],deltabound[1],nuary[0],nuary[-1]],levels=[0,1,2,3],linewidths=4)#,origin="lower",extent=[deltabound[0],deltabound[1],nubound[0],nubound[1]])

#colorbar()
plt.grid()

plt.text(0.68,0.64,'Species 1 wins',size=18)
plt.text(0.62,0.70,'Species 2 wins',size=18)
plt.text(0.67,0.707,'Coexistence',size=14,rotation=50)
plt.text(0.605,0.61,'Extinction',size=14)

plt.text(0.625,0.627,'Region $R$',size=15);
plt.plot([0.66,0.62],[0.66,0.66],'b--',linewidth=3)
plt.plot([0.66,0.62],[0.62,0.62],'b--',linewidth=3)
plt.plot([0.62,0.62],[0.66,0.62],'b--',linewidth=3)
plt.plot([0.66,0.66],[0.66,0.62],'b--',linewidth=3)


plt.xlabel(r'$\mu_{max,1}\quad(d^{-1})$',size=18)
plt.ylabel(r'$\mu_{max,2}\quad(d^{-1})$',size=18)
#title(r'$K_1=0.002,K_2=0.005$',size=16)
plt.savefig('Fig4-2.eps')

# %%
Subnumber1=20
Subnumber2=20
SampleSizeZ=[Subnumber1,Subnumber2]
SampleMatrixZ=np.zeros(SampleSizeZ)
nu1bound=[0.62,0.66]
nu2bound=[0.62,0.66]

em1=np.linspace(nu1bound[0],nu1bound[1],Subnumber1);
en1=np.linspace(nu2bound[0],nu2bound[1],Subnumber2);

# %%
SampleMatrixZ=load('submap.npy')

# %%
plt.figure(figsize=(8,8))
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
#rc('text', usetex=True)

#rcParams['text.usetex'] = True
#imshow(SampleMatrixZ.transpose(),origin='lower',extent=[nu1bound[0],nu1bound[1],nu2bound[0],nu2bound[1]])
plt.contour(SampleMatrixZ.transpose(),extent=[nu1bound[0],nu1bound[1],nu2bound[0],nu2bound[1]],levels=[-2,-0.5,0.5,1,2,3,4,5],linestyles='dotted',linewidths=4)
plt.xlabel(r'$\mu_{max,1}\quad(d^{-1})$',size=20)
plt.ylabel(r'$\mu_{max,2}\quad(d^{-1})$',size=20)
#title(r'$K_1=0.002,K_2=0.005$',size=16)
plt.grid(True)
plt.text(0.6405,0.6405,'Species 1 wins',size=16)
plt.text(0.621,0.65,'Species 2 wins',size=16)
plt.text(0.637,0.6535,'Coexistence',rotation=50,size=16)
plt.text(0.624,0.63,'Extinction',size=16)
plt.savefig('Fig4-3.eps')
#show()

# %%
deg=np.arange(-3,5,0.5)
biNum=np.size(deg)
muRange=np.arange(0.63,0.67,0.0025)
bimuNum=np.size(muRange)

biSize=[bimuNum,biNum]
biMatrix=np.zeros(biSize)

L=10000.

#u10=0.5*numol
#nu=0.08*L
lifeL=2
#print(deg,u10,nu)

# %%
biMatrix=load('bimap.npy')

# %%
plt.figure(figsize=(8,8))
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
#rc('text', usetex=True)


plt.contour(biMatrix.transpose(),extent=[muRange[0],muRange[-1],deg[0],deg[-1]],levels=[-0.5,0.5,1,2,3],linestyles='dotted',linewidths=4)
#imshow(biMatrix)#,extent=[L[0],L[-1],muRange[0],muRange[-1]])
plt.ylabel(r'$\log_{10} \frac {u_2(0)}{u_1(0)}$',size=20)
plt.xlabel(r'$\mu_{max,1}=\mu_{max,2}\quad (d^{-1})$',size=20)
#title(r'$K_1=0.002,K_2=0.005$',size=16)
plt.grid(True)

plt.text(muRange[5],deg[-3]+0.2,'Species 2 wins',size=18)
plt.text(muRange[4],deg[4],'Species 1 wins',size=18)
plt.text(muRange[6]+0.0005,deg[9]+0.1,'Coexistence',size=18)
plt.text(muRange[1]-0.002,deg[-4],'Extinction',size=16)

#colorbar()
plt.savefig('Fig4-4.eps')
